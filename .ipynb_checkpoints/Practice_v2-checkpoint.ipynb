# %% [markdown]
# ## Geocoding and directions for tourist attractions in Austria

# %% [markdown]
# ##### The workflow order is as follows:
# 1. Import libraries
# 2. Import addresses
# 3. Geocode addresses
# 4. Plot addresses
# 5. Select start and end point to plot route

# %%
import openrouteservice as ors
from openrouteservice.directions import directions
import folium
import geopy
import leafmap
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import io
# import streamlit as st
# from streamlit_folium import folium_static

# %%
# pip install openrouteservice
# Out:
# Collecting openrouteservice
#   Using cached openrouteservice-2.3.3-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests>=2.0 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from openrouteservice) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from requests>=2.0->openrouteservice) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from requests>=2.0->openrouteservice) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from requests>=2.0->openrouteservice) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /srv/conda/envs/notebook/lib/python3.8/site-packages (from requests>=2.0->openrouteservice) (3.3)
# Installing collected packages: openrouteservice
# Successfully installed openrouteservice-2.3.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### API Key

# %%
# import config
# performs requests to the ORS API services
# client will be used in all examples
# client = ors.Client(key=config.api_key)

client = ors.Client(key='')

# %% [markdown]
# #### Import addresses
#
# Import addresses in CSV file format

# %%
upload = widgets.FileUpload(
        accept='*.csv',
        multiple=False)
display(upload)
# Out:
# FileUpload(value={}, accept='*.csv', description='Upload')

# %% [markdown]
# #### Data Cleaning
# Inspect the imported data and optimize it for geocoding

# %%
input_file = list(upload.value.values())[0]
content = input_file['content']
content = io.StringIO(content.decode('utf-8'))
df = pd.read_csv(content)
df.head()
# Out:
#      Typ   Nr          Namn           Address1 Address3   Address4  \
# 0  Butik  102  Fältöversten       Karlaplan 13   115 20  STOCKHOLM
# 1  Butik  104           NaN      Nybrogatan 47   114 39  STOCKHOLM
# 2  Butik  106    Garnisonen   Karlavägen 100 A   115 26  STOCKHOLM
# 3  Butik  110           NaN      Hötorgshallen   111 57  STOCKHOLM
# 4  Butik  113        Sergel  Drottninggatan 45   111 21  STOCKHOLM
#
#          Address5       Telefon
# 0  Stockholms län  08/662 22 89
# 1  Stockholms län  08/662 50 16
# 2  Stockholms län  08/662 64 85
# 3  Stockholms län   08/56849241
# 4  Stockholms län   08/21 47 44

# %%
# Merge street, zip and city fields into an address field Using DataFrame.apply() and lambda function

# df["address"] = df["street"].map(str) + ', ' + df["zip"].map(str)+ ', ' + df["city"]+ ', ' +  df['country']
# df.head()

df["address"] = df["Address1"].map(str) + ', ' + df["Address3"].map(str)+ ', ' + df["Address4"] #+ ', ' +  df['country']
df.head()
# Out:
#      Typ   Nr          Namn           Address1 Address3   Address4  \
# 0  Butik  102  Fältöversten       Karlaplan 13   115 20  STOCKHOLM
# 1  Butik  104           NaN      Nybrogatan 47   114 39  STOCKHOLM
# 2  Butik  106    Garnisonen   Karlavägen 100 A   115 26  STOCKHOLM
# 3  Butik  110           NaN      Hötorgshallen   111 57  STOCKHOLM
# 4  Butik  113        Sergel  Drottninggatan 45   111 21  STOCKHOLM
#
#          Address5       Telefon                               address
# 0  Stockholms län  08/662 22 89       Karlaplan 13, 115 20, STOCKHOLM
# 1  Stockholms län  08/662 50 16      Nybrogatan 47, 114 39, STOCKHOLM
# 2  Stockholms län  08/662 64 85   Karlavägen 100 A, 115 26, STOCKHOLM
# 3  Stockholms län   08/56849241      Hötorgshallen, 111 57, STOCKHOLM
# 4  Stockholms län   08/21 47 44  Drottninggatan 45, 111 21, STOCKHOLM

# %% [markdown]
# #### Geocode addresses
# Geocode addresses using geopy library and Nominatim

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
geolocator = Nominatim(user_agent="Practice")

# %%
locator = Nominatim(user_agent="Practice")

geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
df['location'] = df['address'].apply(geocode)

df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else None)

# %%
df.head()
# Out:
#      Typ   Nr          Namn           Address1 Address3   Address4  \
# 0  Butik  102  Fältöversten       Karlaplan 13   115 20  STOCKHOLM
# 1  Butik  104           NaN      Nybrogatan 47   114 39  STOCKHOLM
# 2  Butik  106    Garnisonen   Karlavägen 100 A   115 26  STOCKHOLM
# 3  Butik  110           NaN      Hötorgshallen   111 57  STOCKHOLM
# 4  Butik  113        Sergel  Drottninggatan 45   111 21  STOCKHOLM
#
#          Address5       Telefon                               address  \
# 0  Stockholms län  08/662 22 89       Karlaplan 13, 115 20, STOCKHOLM
# 1  Stockholms län  08/662 50 16      Nybrogatan 47, 114 39, STOCKHOLM
# 2  Stockholms län  08/662 64 85   Karlavägen 100 A, 115 26, STOCKHOLM
# 3  Stockholms län   08/56849241      Hötorgshallen, 111 57, STOCKHOLM
# 4  Stockholms län   08/21 47 44  Drottninggatan 45, 111 21, STOCKHOLM
#
#                                             location  \
# 0  (Karlaplan, Östermalm, Östermalms stadsdelsomr...
# 1  (47, Nybrogatan, Villastaden, Östermalm, Öster...
# 2  (Karlavägen, Östermalm, Östermalms stadsdelsom...
# 3  (Hötorgshallen, Hötorget, Klara, Norrmalm, Nor...
# 4  (Drottninggatan, Klara, Norrmalm, Norrmalms st...
#
#                            point
# 0   (59.337219, 18.0908107, 0.0)
# 1  (59.3372072, 18.0790982, 0.0)
# 2  (59.3361757, 18.0973562, 0.0)
# 3  (59.3343273, 18.0626039, 0.0)
# 4  (59.3357611, 18.0595426, 0.0)

# %% [markdown]
# Drop any colummns with null coordinate values

# %%
df1 = df.dropna()
df1.head()
# Out:
#      Typ   Nr          Namn           Address1 Address3   Address4  \
# 0  Butik  102  Fältöversten       Karlaplan 13   115 20  STOCKHOLM
# 2  Butik  106    Garnisonen   Karlavägen 100 A   115 26  STOCKHOLM
# 4  Butik  113        Sergel  Drottninggatan 45   111 21  STOCKHOLM
# 5  Butik  114      PK-Huset   Norrlandsgatan 3   111 47  STOCKHOLM
# 7  Butik  132     Marieberg   Rålambsvägen 7-9   112 59  STOCKHOLM
#
#          Address5       Telefon                               address  \
# 0  Stockholms län  08/662 22 89       Karlaplan 13, 115 20, STOCKHOLM
# 2  Stockholms län  08/662 64 85   Karlavägen 100 A, 115 26, STOCKHOLM
# 4  Stockholms län   08/21 47 44  Drottninggatan 45, 111 21, STOCKHOLM
# 5  Stockholms län  08/796 98 10   Norrlandsgatan 3, 111 47, STOCKHOLM
# 7  Stockholms län   08/13 30 95   Rålambsvägen 7-9, 112 59, STOCKHOLM
#
#                                             location  \
# 0  (Karlaplan, Östermalm, Östermalms stadsdelsomr...
# 2  (Karlavägen, Östermalm, Östermalms stadsdelsom...
# 4  (Drottninggatan, Klara, Norrmalm, Norrmalms st...
# 5  (3, Norrlandsgatan, Klara, Norrmalm, Norrmalms...
# 7  (Rålambsvägen, Marieberg, Kungsholmens stadsde...
#
#                            point
# 0   (59.337219, 18.0908107, 0.0)
# 2  (59.3361757, 18.0973562, 0.0)
# 4  (59.3357611, 18.0595426, 0.0)
# 5  (59.3331769, 18.0712808, 0.0)
# 7  (59.3284404, 18.0177153, 0.0)

# %%
df.shape
# Out:
# (10, 11)

# %%
# split point column into latitude, longitude and altitude columns
df1[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df1['point'].tolist(), index=df.index)
df1.head()
# Out:
#      Typ   Nr          Namn           Address1 Address3   Address4  \
# 0  Butik  102  Fältöversten       Karlaplan 13   115 20  STOCKHOLM
# 2  Butik  106    Garnisonen   Karlavägen 100 A   115 26  STOCKHOLM
# 4  Butik  113        Sergel  Drottninggatan 45   111 21  STOCKHOLM
# 5  Butik  114      PK-Huset   Norrlandsgatan 3   111 47  STOCKHOLM
# 7  Butik  132     Marieberg   Rålambsvägen 7-9   112 59  STOCKHOLM
#
#          Address5       Telefon                               address  \
# 0  Stockholms län  08/662 22 89       Karlaplan 13, 115 20, STOCKHOLM
# 2  Stockholms län  08/662 64 85   Karlavägen 100 A, 115 26, STOCKHOLM
# 4  Stockholms län   08/21 47 44  Drottninggatan 45, 111 21, STOCKHOLM
# 5  Stockholms län  08/796 98 10   Norrlandsgatan 3, 111 47, STOCKHOLM
# 7  Stockholms län   08/13 30 95   Rålambsvägen 7-9, 112 59, STOCKHOLM
#
#                                             location  \
# 0  (Karlaplan, Östermalm, Östermalms stadsdelsomr...
# 2  (Karlavägen, Östermalm, Östermalms stadsdelsom...
# 4  (Drottninggatan, Klara, Norrmalm, Norrmalms st...
# 5  (3, Norrlandsgatan, Klara, Norrmalm, Norrmalms...
# 7  (Rålambsvägen, Marieberg, Kungsholmens stadsde...
#
#                            point   latitude  longitude  altitude
# 0   (59.337219, 18.0908107, 0.0)  59.337219  18.090811       0.0
# 2  (59.3361757, 18.0973562, 0.0)  59.336176  18.097356       0.0
# 4  (59.3357611, 18.0595426, 0.0)  59.335761  18.059543       0.0
# 5  (59.3331769, 18.0712808, 0.0)  59.333177  18.071281       0.0
# 7  (59.3284404, 18.0177153, 0.0)  59.328440  18.017715       0.0

# %%
df1 = df1.drop(['Address1', 'Address3', 'Address4', 'Address5'], axis=1)

# %%
df1.head()
# Out:
#      Typ   Nr          Namn       Telefon  \
# 0  Butik  102  Fältöversten  08/662 22 89
# 2  Butik  106    Garnisonen  08/662 64 85
# 4  Butik  113        Sergel   08/21 47 44
# 5  Butik  114      PK-Huset  08/796 98 10
# 7  Butik  132     Marieberg   08/13 30 95
#
#                                 address  \
# 0       Karlaplan 13, 115 20, STOCKHOLM
# 2   Karlavägen 100 A, 115 26, STOCKHOLM
# 4  Drottninggatan 45, 111 21, STOCKHOLM
# 5   Norrlandsgatan 3, 111 47, STOCKHOLM
# 7   Rålambsvägen 7-9, 112 59, STOCKHOLM
#
#                                             location  \
# 0  (Karlaplan, Östermalm, Östermalms stadsdelsomr...
# 2  (Karlavägen, Östermalm, Östermalms stadsdelsom...
# 4  (Drottninggatan, Klara, Norrmalm, Norrmalms st...
# 5  (3, Norrlandsgatan, Klara, Norrmalm, Norrmalms...
# 7  (Rålambsvägen, Marieberg, Kungsholmens stadsde...
#
#                            point   latitude  longitude  altitude
# 0   (59.337219, 18.0908107, 0.0)  59.337219  18.090811       0.0
# 2  (59.3361757, 18.0973562, 0.0)  59.336176  18.097356       0.0
# 4  (59.3357611, 18.0595426, 0.0)  59.335761  18.059543       0.0
# 5  (59.3331769, 18.0712808, 0.0)  59.333177  18.071281       0.0
# 7  (59.3284404, 18.0177153, 0.0)  59.328440  18.017715       0.0

# %% [markdown]
# #### Plot addresses
# Plot geocoded addresses using folium and leafmap mapping libraries

# %%
map1 = folium.Map(
    location=[50.1109,8.6821],
    tiles='openstreetmap',
    zoom_start=6,
)

df1.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bd6443b87ce3235870ba98a8be3e0c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bd6443b87ce3235870ba98a8be3e0c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9bd6443b87ce3235870ba98a8be3e0c7 = L.map(
#                 &quot;map_9bd6443b87ce3235870ba98a8be3e0c7&quot;,
#                 {
#                     center: [50.1109, 8.6821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cb16ea34872be5a78ee9b6821eea9ba = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_7db40e05b2116f31071524101d1753ac = L.circleMarker(
#                 [59.337219, 18.0908107],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_af633f686d00f512b6947363d6896aab = L.circleMarker(
#                 [59.3361757, 18.0973562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_b3f35444b00cf32c25093df8e89aa729 = L.circleMarker(
#                 [59.3357611, 18.0595426],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_e29edd99cbd4b0efeb3ce1094881938d = L.circleMarker(
#                 [59.3331769, 18.0712808],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_d4099454439d7f9a0e2a9c3c65088c25 = L.circleMarker(
#                 [59.3284404, 18.0177153],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_1b1d3ad2e5aa92b7937f89fc730d5f7b = L.circleMarker(
#                 [59.3464104, 18.0332565],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9bd6443b87ce3235870ba98a8be3e0c7);
#
#
#             var circle_marker_4b2f85415fdaaa728eaf5bb8f2969b2d = L.circleMarker(
#                 [59.3434945, 18.0528016],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&

# %%
Map = leafmap.Map(center=(50.1109,8.6821), zoom=5)
Map.add_xy_data(df1, x="longitude", y="latitude", layer_name="restaurants")
Map
# Out:
# Map(center=[50.1109, 8.6821], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %% [markdown]
# #### Routing from start point to end point
# Implement routing using openroutes service library

# %% [markdown]
# # widgets
# start_dropdown = widgets.Dropdown(options=list(df.address),
#                                      value=list(df.address)[0],
#                                      description='start:',
#                                      disabled=False)
#
# end_dropdown = widgets.Dropdown(options=list(df.address),
#                                    value=list(df.address)[1],
#                                    description='end:',
#                                    disabled=False)
#
# # function
# # calculate distance from a to b
# # display map with ant path from a to b
# def get_coordinates(a, b):
#     start_lat = df[df.address == a].latitude.values[0]
#     start_long = df[df.address == a].longitude.values[0]
#     end_lat = df[df.address == b].latitude.values[0]
#     end_long = df[df.address == b].longitude.values[0]
#     start, end = (start_lat, start_long), (end_lat, end_long)
#
#     m = Map(center=(50.1109,8.6821), zoom=5, scroll_wheel_zoom=True)
#     ant_path = AntPath(locations=[start, end])
#     m.add_layer(ant_path)
#     measure = MeasureControl(position='topleft', active_color='red', primary_length_unit='miles')
#     m.add_control(measure)
#     display(m)
#
#     return distance.distance(start, end).miles
#
# # interaction between function and widget
# widgets.interact(get_coordinates, a=start_dropdown, b=end_dropdown);

# %%
df1
# Out:
#       Typ   Nr              Namn       Telefon  \
# 0   Butik  102      Fältöversten  08/662 22 89
# 2   Butik  106        Garnisonen  08/662 64 85
# 4   Butik  113            Sergel   08/21 47 44
# 5   Butik  114          PK-Huset  08/796 98 10
# 7   Butik  132         Marieberg   08/13 30 95
# 12  Butik  140          Torsplan   08/31 73 49
# 13  Butik  143          Odenplan   08/32 35 29
# 14  Butik  144         Jarlaplan   08/24 31 15
# 19  Butik  166     Söderhallarna  08/641 86 75
# 23  Butik  173  Hammarby Sjöstad  08/640 00 44
#
#                                     address  \
# 0           Karlaplan 13, 115 20, STOCKHOLM
# 2       Karlavägen 100 A, 115 26, STOCKHOLM
# 4      Drottninggatan 45, 111 21, STOCKHOLM
# 5       Norrlandsgatan 3, 111 47, STOCKHOLM
# 7       Rålambsvägen 7-9, 112 59, STOCKHOLM
# 12         Solnavägen 2b, 113 65, STOCKHOLM
# 13          Odengatan 58, 113 22, STOCKHOLM
# 14  Birger Jarlsgatan 84, 114 20, STOCKHOLM
# 19    Medborgarplatsen 3, 118 26, STOCKHOLM
# 23    Lugnets Allé 26-28, 120 66, STOCKHOLM
#
#                                              location  \
# 0   (Karlaplan, Östermalm, Östermalms stadsdelsomr...
# 2   (Karlavägen, Östermalm, Östermalms stadsdelsom...
# 4   (Drottninggatan, Klara, Norrmalm, Norrmalms st...
# 5   (3, Norrlandsgatan, Klara, Norrmalm, Norrmalms...
# 7   (Rålambsvägen, Marieberg, Kungsholmens stadsde...
# 12  (2B, Solnavägen, Röda bergen, Vasastaden, Norr...
# 13  (58, Odengatan, Sibirien, Vasastaden, Norrmalm...
# 14  (84, Birger Jarlsgatan, Lärkstaden, Östermalm,...
# 19  (3, Medborgarplatsen, Södermalm, Södermalms st...
# 23  (26-28, Lugnets Allé, Södra Hammarbyhamnen, Sö...
#
#                             point   latitude  longitude  altitude
# 0    (59.337219, 18.0908107, 0.0)  59.337219  18.090811       0.0
# 2   (59.3361757, 18.0973562, 0.0)  59.336176  18.097356       0.0
# 4   (59.3357611, 18.0595426, 0.0)  59.335761  18.059543       0.0
# 5   (59.3331769, 18.0712808, 0.0)  59.333177  18.071281       0.0
# 7   (59.3284404, 18.0177153, 0.0)  59.328440  18.017715       0.0
# 12  (59.3464104, 18.0332565, 0.0)  59.346410  18.033257       0.0
# 13  (59.3434945, 18.0528016, 0.0)  59.343494  18.052802       0.0
# 14   (59.3446986, 18.063395, 0.0)  59.344699  18.063395       0.0
# 19  (59.3144846, 18.0712026, 0.0)  59.314485  18.071203       0.0
# 23  (59.3023089, 18.1034195, 0.0)  59.302309  18.103420       0.0

# %%
df1.address
# Out:
# 0             Karlaplan 13, 115 20, STOCKHOLM
# 2         Karlavägen 100 A, 115 26, STOCKHOLM
# 4        Drottninggatan 45, 111 21, STOCKHOLM
# 5         Norrlandsgatan 3, 111 47, STOCKHOLM
# 7         Rålambsvägen 7-9, 112 59, STOCKHOLM
# 12           Solnavägen 2b, 113 65, STOCKHOLM
# 13            Odengatan 58, 113 22, STOCKHOLM
# 14    Birger Jarlsgatan 84, 114 20, STOCKHOLM
# 19      Medborgarplatsen 3, 118 26, STOCKHOLM
# 23      Lugnets Allé 26-28, 120 66, STOCKHOLM
# Name: address, dtype: object

# %%
start_dropdown = widgets.Dropdown(options=list(df1.address),
                                     value=list(df1.address)[2],
                                     description='start:',
                                     disabled=False)
start_dropdown
# Out:
# Dropdown(description='start:', index=2, options=('Karlaplan 13, 115 20, STOCKHOLM', 'Karlavägen 100 A, 115 26,…

# %%
end_dropdown = widgets.Dropdown(options=list(df1.address),
                                   value=list(df1.address)[3],
                                   description='end:',
                                   disabled=False)
end_dropdown
# Out:
# Dropdown(description='end:', index=3, options=('Karlaplan 13, 115 20, STOCKHOLM', 'Karlavägen 100 A, 115 26, S…

# %%
#store selected dropdown values
starter = start_dropdown.value
ender = end_dropdown.value

print('start_dropdown :',starter)
print('end_dropdown :',ender)

# # interaction between function and widget
# widgets.interact(get_coordinates, a=start_dropdown, b=end_dropdown);
def get_coordinates(starter, ender):
    start_lat = df1[df1.address == starter].latitude.values[0]
    start_long = df1[df1.address == starter].longitude.values[0]
    end_lat = df1[df1.address == ender].latitude.values[0]
    end_long = df1[df1.address == ender].longitude.values[0]
    start, end = ((start_long, start_lat), (end_long, end_lat))
    return start, end

# call fn and return start, end coordinates
start_and_end = get_coordinates(starter,ender)

#reverse zoom center point, refered from start coordinates. should be [lat lon]
start_loc = list(start_and_end[0])
start_loc[1],start_loc[0] = start_loc[0], start_loc[1]
end_loc = list(start_and_end[1])
end_loc[1],end_loc[0] = end_loc[0], end_loc[1]


#store markers coordinates and labels
marks =[start_loc, end_loc]
marks_popup=[starter,ender]


# directions
route = client.directions(coordinates=start_and_end,
                          profile='driving-car', 
                          format='geojson')


def get_distance_and_time(route):
    level1 = route['features']
    level2 =list(level1)[0].get('properties')
    level3= level2.get('summary')
    #store distance traveled
    distance = level3.get('distance')
    #store trip duration
    duration = (level3.get('duration')/60)
    print('Distance Travelled : ', round(distance/1000,2), 'km')
    print('Trip duration : ', round(duration,2), 'mins')
    return distance, duration


#execute get_distance_time()
route_details = get_distance_and_time(route)
distance_traveled, time_traveled = route_details[0], route_details[1]


#location wants lat lon
# define empty map
map_directions = folium.Map(location=start_loc, zoom_start=12.5)

# add geojson of route to map
folium.GeoJson(route, name='route').add_to(map_directions)

# add layer control to map (allows layer to be turned on or off)
folium.LayerControl().add_to(map_directions)

# add markers on start and end
for i in range(len(marks)):
    folium.Marker(location=marks[i], popup=marks_popup[i]).add_to(map_directions)

# display map
map_directions
# Out:
# start_dropdown : Rålambsvägen 7-9, 112 59, STOCKHOLM
# end_dropdown : Birger Jarlsgatan 84, 114 20, STOCKHOLM
# ((18.0177153, 59.3284404), (18.063395, 59.3446986))
# Distance Travelled :  4.81 km
# Trip duration :  10.75 mins
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_770e75cb7ca1d53070a5c8e12e1bd6d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_770e75cb7ca1d53070a5c8e12e1bd6d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_770e75cb7ca1d53070a5c8e12e1bd6d7 = L.map(
#                 &quot;map_770e75cb7ca1d53070a5c8e12e1bd6d7&quot;,
#                 {
#                     center: [59.3284404, 18.0177153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d814453afc5f0f2dc26903010ddcb367 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_770e75cb7ca1d53070a5c8e12e1bd6d7);
#
#
#
#         function geo_json_a98c95779fe2a56ca9021eb2b9070872_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_
18.048616, 59.342286], [18.048838, 59.342341], [18.049049, 59.342394], [18.049909, 59.342602], [18.05085, 59.342832], [18.050932, 59.342851], [18.050986, 59.342865], [18.051069, 59.342884], [18.052275, 59.343147], [18.053487, 59.34345], [18.053572, 59.343472], [18.054028, 59.343589], [18.05521, 59.34387], [18.055327, 59.343899], [18.055498, 59.343941], [18.055664, 59.343979], [18.05594, 59.344036], [18.056463, 59.344162], [18.056901, 59.344275], [18.057552, 59.344449], [18.057666, 59.344479], [18.057913, 59.344541], [18.058065, 59.344579], [18.059444, 59.344928], [18.059613, 59.344968], [18.059869, 59.345017], [18.06079, 59.345247], [18.060973, 59.345299], [18.061233, 59.345368], [18.062436, 59.345672], [18.062514, 59.345691], [18.062538, 59.345665], [18.062991, 59.345183], [18.063011, 59.345148], [18.063015, 59.345076], [18.063017, 59.344916], [

# %%
#inspecting route path
route
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'bbox': [18.033072, 59.337224, 18.091317, 59.346327],
#    'type': 'Feature',
#    'properties': {'segments': [{'distance': 4028.2,
#       'duration': 504.1,
#       'steps': [{'distance': 1922.8,
#         'duration': 232.1,
#         'type': 11,
#         'instruction': 'Head northeast on Karlavägen',
#         'name': 'Karlavägen',
#         'way_points': [0, 76]},
#        {'distance': 97.4,
#         'duration': 20.9,
#         'type': 13,
#         'instruction': 'Keep right onto Karlavägen',
#         'name': 'Karlavägen',
#         'way_points': [76, 84]},
#        {'distance': 932.3,
#         'duration': 102.3,
#         'type': 0,
#         'instruction': 'Turn left onto Odengatan',
#         'name': 'Odengatan',
#         'way_points': [84, 109]},
#        {'distance': 604.7,
#         'duration': 87.7,
#         'type': 6,
#         'instruction': 'Continue straight onto Karlbergsvägen',
#         'name': 'Karlbergsvägen',
#         'way_points': [109, 132]},
#        {'distance': 470.9,
#         'duration': 61.1,
#         'type': 1,
#         'instruction': 'Turn right onto Torsgatan',
#         'name': 'Torsgatan',
#         'way_points': [132, 150]},
#        {'distance': 0.0,
#         'duration': 0.0,
#         'type': 10,
#         'instruction': 'Arrive at Torsgatan, on the right',
#         'name': '-',
#         'way_points': [150, 150]}]}],
#     'summary': {'distance': 4028.2, 'duration': 504.1},
#     'way_points': [0, 150]},
#    'geometry': {'coordinates': [[18.090802, 59.337224],
#      [18.090996, 59.337319],
#      [18.091033, 59.337342],
#      [18.091078, 59.337392],
#      [18.091126, 59.337462],
#      [18.091195, 59.337571],
#      [18.091306, 59.337765],
#      [18.091317, 59.337877],
#      [18.091264, 59.33796],
#      [18.091013, 59.338101],
#      [18.090982, 59.338116],
#      [18.090915, 59.338156],
#      [18.090649, 59.338263],
#      [18.09033, 59.338314],
#      [18.09012, 59.338318],
#      [18.08996, 59.338315],
#      [18.089805, 59.338309],
#      [18.089408, 59.338257],
#      [18.089314, 59.338205],
#      [18.089168, 59.338054],
#      [18.089121, 59.338013],
#      [18.088966, 59.338034],
#      [18.088, 59.338222],
#      [18.087841, 59.338255],
#      [18.087758, 59.338271],
#      [18.086658, 59.338501],
#      [18.086521, 59.338532],
#      [18.086392, 59.338558],
#      [18.037054, 59.342557],
#      [18.036781, 59.342543],
#      [18.036713, 59.34254],
#      [18.036623, 59.342647],
#      [18.035447, 59.343995],
#      [18.035379, 59.344082],
#      [18.035356, 59.344113],
#      [18.035301, 59.344171],
#      [18.03514, 59.344362],
#      [18.03476, 59.344791],
#      [18.03438, 59.345219],
#      [18.034345, 59.345261],
#      [18.034029, 59.345642],
#      [18.033899, 59.345748],
#      [18.0338, 59.345822],
#      [18.033635, 59.345936],
#      [18.033473, 59.346059],
#      [18.033409, 59.346107],
#      [18.033335, 59.346162],
#      [18.033245, 59.346228],
#      [18.033072, 59.346327]],
#     'type': 'LineString'}}],
#  'bbox': [18.033072, 59.337224, 18.091317, 59.346327],
#  'metadata': {'attribution': 'openrouteservice.org | OpenStreetMap contributors',
#   'service': 'routing',
#   'timestamp': 1661556154427,
#   'query': {'coordinates': [[18.0908107, 59.337219], [18.0332565, 59.3464104]],
#    'profile': 'driving-car',
#    'format': 'geojson'},
#   'engine': {'version': '6.7.0',
#    'build_date': '2022-02-18T19:37:41Z',
#    'graph_date': '2022-08-14T14:40:44Z'}}}

# %%
# scratch

# #store dropdown values
# a = start_dropdown.value
# b= end_dropdown.value

# print('start_dropdown :',start_dropdown.value)
# print('end_dropdown :',end_dropdown.value)

# # # interaction between function and widget
# # widgets.interact(get_coordinates, a=start_dropdown, b=end_dropdown);
# def get_coordinates(a,b):
#     start_lat = df1[df1.address == a].latitude.values[0]
#     start_long = df1[df1.address == a].longitude.values[0]
#     end_lat = df1[df1.address == b].latitude.values[0]
#     end_long = df1[df1.address == b].longitude.values[0]
#     start, end = ((start_long, start_lat), (end_long, end_lat))
#     return start, end

# # call fn and return start, end coordinates
# abc = get_coordinates(a,b)


# #reverse zoom center point, refered from start coordinates. should be [lat lon]
# zoom_loc= list(abc[0])
# zoom_loc[1],zoom_loc[0] = zoom_loc[0], zoom_loc[1]



# # directions
# route = client.directions(coordinates=abc,
#                           profile='driving-car',
#                           format='geojson')
# #location wants lat lon
# # map
# map_directions = folium.Map(location=zoom_loc, zoom_start=12)

# # add geojson to map
# folium.GeoJson(route, name='route').add_to(map_directions)

# # add layer control to map (allows layer to be turned on or off)
# folium.LayerControl().add_to(map_directions)

# # display map
# map_directions
# Out:
# start_dropdown : Karlaplan 13, 115 20, STOCKHOLM
# end_dropdown : Solnavägen 2b, 113 65, STOCKHOLM
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dfeec66bd3259e3b331d6a777a37630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dfeec66bd3259e3b331d6a777a37630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1dfeec66bd3259e3b331d6a777a37630 = L.map(
#                 &quot;map_1dfeec66bd3259e3b331d6a777a37630&quot;,
#                 {
#                     center: [59.337219, 18.0908107],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a3a066c849511326337aa0b2eb6bd36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1dfeec66bd3259e3b331d6a777a37630);
#
#
#
#         function geo_json_857cd0e7f09c6967480d19f6a46078b8_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_857cd0e7f09c6967480d19f6a46078b8 = L.geoJson(null, {
#                 onEachFeature: geo_json
, 59.342851], [18.04488, 59.342846], [18.044494, 59.34283], [18.044151, 59.342818], [18.042569, 59.342764], [18.042491, 59.342761], [18.042397, 59.342757], [18.040788, 59.342698], [18.040544, 59.342689], [18.04031, 59.34268], [18.038845, 59.342627], [18.038737, 59.342625], [18.038569, 59.342621], [18.038505, 59.342619], [18.038336, 59.342614], [18.037714, 59.342577], [18.037054, 59.342557], [18.036781, 59.342543], [18.036713, 59.34254], [18.036623, 59.342647], [18.035447, 59.343995], [18.035379, 59.344082], [18.035356, 59.344113], [18.035301, 59.344171], [18.03514, 59.344362], [18.03476, 59.344791], [18.03438, 59.345219], [18.034345, 59.345261], [18.034029, 59.345642],

# %%
# # m = Map(center=(38, -98), zoom=4, scroll_wheel_zoom=True)
# m= map_directions
# ant_path = AntPath(locations=[start, end])
# m.add_layer(ant_path)
# measure = MeasureControl(position='topleft', active_color='red', primary_length_unit='miles')
# m.add_control(measure)
# display(m)

# %%
# start_dropdown = widgets.Dropdown(options=list(df.address),
#                                      value=list(df.address)[0],
#                                      description='start:',
#                                      disabled=False)

# end_dropdown = widgets.Dropdown(options=list(df.address),
#                                    value=list(df.address)[1],
#                                    description='end:',
#                                    disabled=False)

# def get_coordinates(a, b):
#     start_lat = df[df.address == a].latitude.values[0]
#     start_long = df[df.address == a].longitude.values[0]
#     end_lat = df[df.address == b].latitude.values[0]
#     end_long = df[df.address == b].longitude.values[0]
#     start, end = (start_lat, start_long), (end_lat, end_long)
#     coordinates = [[start_lat, start_long], [end_lat, end_long]]

#     route = client.directions(coordinates=coordinates,
#                           profile='driving-car',
#                           format='geojson')


#     map_directions = folium.Map(location=[33.77, -84.37], zoom_start=5)
#     folium.GeoJson(route, name='route').add_to(map_directions)

#     folium.LayerControl().add_to(map_directions)

#     map_directions
    
    
#     m = Map(center=(38, -98), zoom=4, scroll_wheel_zoom=True)
#     ant_path = AntPath(locations=[start, end])
#     m.add_layer(ant_path)
#     measure = MeasureControl(position='topleft', active_color='red', primary_length_unit='miles')
#     m.add_control(measure)
#     display(m)
    
#     return distance.distance(start, end).miles




# # directions
# route = client.directions(coordinates=coordinates,
#                           profile='driving-car',
#                           format='geojson')

# # map
# map_directions = folium.Map(location=[33.77, -84.37], zoom_start=5)

# # add geojson to map
# folium.GeoJson(route, name='route').add_to(map_directions)

# # add layer control to map (allows layer to be turned on or off)
# folium.LayerControl().add_to(map_directions)

# # display map
# map_directions





# # interaction between function and widget
# ipywidgets.interact(get_coordinates, a=start_dropdown, b=end_dropdown);

# %% [markdown]
# # coordinates from Nashville, TN (-86.781247, 36.163532) to Miami, FL (-80.191850, 25.771645)
# # order for coordinates is [lon, lat]
# coordinates = [[-86.781247, 36.163532], [-80.191850, 25.771645]]
#
# # directions
# route = client.directions(coordinates=coordinates,
#                           profile='driving-car',
#                           format='geojson')
#
# # map
# map_directions = folium.Map(location=[33.77, -84.37], zoom_start=5)
#
# # add geojson to map
# folium.GeoJson(route, name='route').add_to(map_directions)
#
# # add layer control to map (allows layer to be turned on or off)
# folium.LayerControl().add_to(map_directions)
#
# # display map
# map_directions
